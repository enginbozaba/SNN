# %% [markdown]
# # Sinaps

# %% [markdown]
# Hücre aksonlarının diğer dentritlerle olan bağlantısını sağlar. SNN 'de , bir nörondan diğer bağlı nöronlara üretilen uyarıların(spike-dikenlerin) ağırlıklı yoludur.

# %%
from IPython.display import Image
Image(filename='synapse.png')
