# %% [markdown]
# # Giriş

# %% [markdown]
# Spiking sinir ağları ( SNN ), üçüncü nesil sinir ağlarıdır.
#
# SNN, her bir uyaran üzerinde reaksiyona girmez, bunun yerine, bir eşik potansiyeline ulaşana ve bir “başak” oluşturacak şekilde girdiler biriktirir.
#
# Doğaları gereği, SNN'ler gradyan alçalma kullanarak 2. nesil sinir ağları gibi eğitilemezler.
#
# Spike Zamanlama Bağımlı Plastisite ( STDP ), SNN'ler için denetlenmeyen bir eğitim yönteminden ilham alan biyolojik bir süreçtir.
#
# Bu makalede, STDP'nin sürekli bir giriş sivri akışı içinde tekrarlanan bir paterni tanımlamak için nasıl tek bir nöron öğretmek için kullanılabileceğine dair bir örnek vereceğim.
#
# http://www.kaizou.org/2018/07/stdp-tensorflow/

# %%
from IPython.display import Image
Image(filename='LIFneuron.jpg')

# %%
pwd
# Out:
# 'C:\\Users\\Engin Bozaba\\AppData\\Roaming\\SPB_16.6\\Untitled Folder'
